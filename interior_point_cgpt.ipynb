# %%
import numpy as np

# %%
# Helper function to compute the residuals
def compute_residuals(A, b, c, x, y, s):
    r_d = c - A.T @ y - s  # Dual residual
    r_p = A @ x - b        # Primal residual
    r_c = x * s            # Complementarity residual
    return r_p, r_d, r_c

# Primal-Dual Path-Following Interior Point Method
def primal_dual_path_following(A, b, c, tol=1e-8, max_iter=100):
    m, n = A.shape

    # Initial feasible guess
    x = np.ones(n)
    y = np.ones(m)
    s = np.ones(n)

    for k in range(max_iter):
        # Compute residuals
        r_p, r_d, r_c = compute_residuals(A, b, c, x, y, s)

        # Check for convergence
        if np.linalg.norm(r_p) < tol and np.linalg.norm(r_d) < tol and np.linalg.norm(r_c) < tol:
            print(f"Converged in {k} iterations.")
            return x, y, s

        # Centering parameter (mu)
        mu = (x @ s) / n

        # Form the KKT matrix and the right-hand side
        X_inv = np.diag(1 / x)
        S = np.diag(s)

        KKT = np.block([
            [np.zeros((n, n)), A.T, np.eye(n)],
            [A, np.zeros((m, m)), np.zeros((m, n))],
            [S, np.zeros((n, m)), X_inv]
        ])

        rhs = np.hstack([
            -r_d,
            -r_p,
            -r_c + mu * np.ones(n)
        ])

        # Solve for search direction
        delta = np.linalg.solve(KKT, rhs)

        delta_x = delta[:n]
        delta_y = delta[n:n+m]
        delta_s = delta[n+m:]

        # Line search for step size
        alpha = 1.0
        beta = 0.9
        while np.any(x + alpha * delta_x <= 0) or np.any(s + alpha * delta_s <= 0):
            alpha *= beta

        # Update variables
        x += alpha * delta_x
        y += alpha * delta_y
        s += alpha * delta_s

        objective_value = c @ x
        print(f"Iteration {k}: Objective Value = {objective_value}")



    print("Maximum iterations reached without convergence.")
    return x, y, s

# Example problem
A = np.array([[1, 2, 3], [4, 5, 6]])
b = np.array([7, 8])
c = np.array([1, 2, 3])

x, y, s = primal_dual_path_following(A, b, c)
print("Optimal x:", x)

objective_value = c @ x
print(f"::::::::::::::::::::::::::::::::::: Objective Value = {objective_value}")
# Out:
# Iteration 0: Objective Value = 6.228767924549611
# Iteration 1: Objective Value = 6.244405086453467
# Iteration 2: Objective Value = 6.244656691729094
# Iteration 3: Objective Value = 6.244674748406512
# Iteration 4: Objective Value = 6.244674942967321
# Iteration 5: Objective Value = 6.244674956934798
# Iteration 6: Objective Value = 6.244674957366437
# Iteration 7: Objective Value = 6.244674957377242
# Iteration 8: Objective Value = 6.244674957377371
# Iteration 9: Objective Value = 6.244674957377375
# Iteration 10: Objective Value = 6.244674957377375
# Iteration 11: Objective Value = 6.244674957377375
# Iteration 12: Objective Value = 6.244674957377375
# Iteration 13: Objective Value = 6.244674957377375
# Iteration 14: Objective Value = 6.244674957377375
# Iteration 15: Objective Value = 6.244674957377375
# Iteration 16: Objective Value = 6.244674957377375
# Iteration 17: Objective Value = 6.244674957377375
# Iteration 18: Objective Value = 6.244674957377375
# Iteration 19: Objective Value = 6.244674957377375
# Iteration 20: Objective Value = 6.244674957377375
# Iteration 21: Objective Value = 6.244674957377375
# Iteration 22: Objective Value = 6.244674957377375
# Iteration 23: Objective Value = 6.244674957377375
# Iteration 24: Objective Value = 6.244674957377375
# Iteration 25: Objective Value = 6.244674957377375
# Iteration 26: Objective Value = 6.244674957377375
# Iteration 27: Objective Value = 6.244674957377375
# Iteration 28: Objective Value = 6.244674957377375
# Iteration 29: Objective Value = 6.244674957377375
# Iteration 30: Objective Value = 6.244674957377375
# Iteration 31: Objective Value = 6.244674957377375
# Iteration 32: Objective Value = 6.244674957377375
# Iteration 33: Objective Value = 6.244674957377375
# Iteration 34: Objective Value = 6.244674957377375
# Iteration 35: Objective Value = 6.244674957377375
# Iteration 36: Objective Value = 6.244674957377375
# Iteration 37: Objective Value = 6.244674957377375
# Iteration 38: Objective Value = 6.244674957377375
# Iteration 39: Objective Value = 6.244674957377375
# Iteration 40: Objective Value = 6.244674957377375
# Iteration 41: Objective Value = 6.244674957377375
# Iteration 42: Objective Value = 6.244674957377375
# Iteration 43: Objective Value = 6.244674957377375
# Iteration 44: Objective Value = 6.244674957377375
# Iteration 45: Objective Value = 6.244674957377375
# Iteration 46: Objective Value = 6.244674957377375
# Iteration 47: Objective Value = 6.244674957377375
# Iteration 48: Objective Value = 6.244674957377375
# Iteration 49: Objective Value = 6.244674957377375
# Iteration 50: Objective Value = 6.244674957377375
# Iteration 51: Objective Value = 6.244674957377375
# Iteration 52: Objective Value = 6.244674957377375
# Iteration 53: Objective Value = 6.244674957377375
# Iteration 54: Objective Value = 6.244674957377375
# Iteration 55: Objective Value = 6.244674957377375
# Iteration 56: Objective Value = 6.244674957377375
# Iteration 57: Objective Value = 6.244674957377375
# Iteration 58: Objective Value = 6.244674957377375
# Iteration 59: Objective Value = 6.244674957377375
# Iteration 60: Objective Value = 6.244674957377375
# Iteration 61: Objective Value = 6.244674957377375
# Iteration 62: Objective Value = 6.244674957377375
# Iteration 63: Objective Value = 6.244674957377375
# Iteration 64: Objective Value = 6.244674957377375
# Iteration 65: Objective Value = 6.244674957377375
# Iteration 66: Objective Value = 6.244674957377375
# Iteration 67: Objective Value = 6.244674957377375
# Iteration 68: Objective Value = 6.244674957377375
# Iteration 69: Objective Value = 6.244674957377375
# Iteration 70: Objective Value = 6.244674957377375
# Iteration 71: Objective Value = 6.244674957377375
# Iteration 72: Objective Value = 6.244674957377375
# Iteration 73: Objective Value = 6.244674957377375
# Iteration 74: Objective Value = 6.244674957377375
# Iteration 75: Objective Value = 6.244674957377375
# Iteration 76: Objective Value = 6.244674957377375
# Iteration 77: Objective Value = 6.244674957377375
# Iteration 78: Objective Value = 6.244674957377375
# Iteration 79: Objective Value = 6.244674957377375
# Iteration 80: Objective Value = 6.244674957377375
# Iteration 81: Objective Value = 6.244674957377375
# Iteration 82: Objective Value = 6.244674957377375
# Iteration 83: Objective Value = 6.244674957377375
# Iteration 84: Objective Value = 6.244674957377375
# Iteration 85: Objective Value = 6.244674957377375
# Iteration 86: Objective Value = 6.244674957377375
# Iteration 87: Objective Value = 6.244674957377375
# Iteration 88: Objective Value = 6.244674957377375
# Iteration 89: Objective Value = 6.244674957377375
# Iteration 90: Objective Value = 6.244674957377375
# Iteration 91: Objective Value = 6.244674957377375
# Iteration 92: Objective Value = 6.244674957377375
# Iteration 93: Objective Value = 6.244674957377375
# Iteration 94: Objective Value = 6.244674957377375
# Iteration 95: Objective Value = 6.244674957377375
# Iteration 96: Objective Value = 6.244674957377375
# Iteration 97: Objective Value = 6.244674957377375
# Iteration 98: Objective Value = 6.244674957377375
# Iteration 99: Objective Value = 6.244674957377375
# Maximum iterations reached without convergence.
# Optimal x: [4.36144005e-149 7.97925384e-001 1.54960806e+000]
# ::::::::::::::::::::::::::::::::::: Objective Value = 6.244674957377375
